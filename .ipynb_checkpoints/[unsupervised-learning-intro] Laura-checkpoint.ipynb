# %%
import pandas as pd
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Using a Dataset from kaggle because of rate limit issues with spotify

# %%
pd.set_option('display.max_columns', None)

# %%
songs = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\19_Advanced_Machine_Learning\dataset.csv")
songs
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %% [markdown]
# Using only song_features to create model

# %%
X = songs[['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness',
           'liveness','valence','tempo']]
X
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1              0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2              0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3              0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4              0.618  0.4430    2    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.172  0.2350    5   -16.393     1       0.0422        0.6400
# 113996         0.174  0.1170    0   -18.318     0       0.0401        0.9940
# 113997         0.629  0.3290    0   -10.895     0       0.0420        0.8670
# 113998         0.587  0.5060    7   -10.889     1       0.0297        0.3810
# 113999         0.526  0.4870    1   -10.204     0       0.0725        0.6810
#
# ...

# %% [markdown]
# Standarisation

# %%
from sklearn.preprocessing import StandardScaler

X_prep = StandardScaler().fit_transform(X)

# make it a df again to see the .decripbe()
X_df = pd.DataFrame(X_prep, columns = X.columns)
X_df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  1.140000e+05  1.140000e+05  1.140000e+05  1.140000e+05  1.140000e+05
# mean  -9.338264e-16 -5.434688e-16 -1.288484e-15 -1.096540e-16 -6.353203e-16
# std    1.000004e+00  1.000004e+00  1.000004e+00  1.000004e+00  1.000004e+00
# min   -3.266080e+00 -2.549946e+00 -1.491343e+00 -8.206295e+00 -1.326281e+00
# 25%   -6.384647e-01 -6.734152e-01 -9.295412e-01 -3.487632e-01 -1.326281e+00
# 50%    7.606216e-02  1.734091e-01 -8.683787e-02  2.495291e-01  7.539880e-01
# 75%    7.387282e-01  8.453026e-01  7.558655e-01  6.473964e-01  7.539880e-01
# max    2.409799e+00  1.425755e+00  1.598569e+00  2.543281e+00  7.539880e-01
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  1.140000e+05  1.140000e+05      1.140000e+05  1.140000e+05
# mean   4.784891e-17  1.197152e-15     -1.732076e-14 -1.593045e-15
# std    1.000004e+00  1.000004e+00      1.000004e+00  1.000004e+00
# ...

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 8, random_state = 0)
kmeans.fit(X_prep)
# Out:
# C:\Users\ljant\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(random_state=0)

# %%
kmeans.inertia_

# %%
clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([4, 2, 2, ..., 2, 2, 2])

# %%
X_df_upd = pd.DataFrame(X_df)
X_df_upd["cluster"] = clusters
X_df_upd
# Out:
#         danceability    energy       key  loudness      mode  speechiness  \
# 0           0.629244 -0.717148 -1.210442  0.300828 -1.326281     0.551848
# 1          -0.845908 -1.889980 -1.210442 -1.784744  0.753988    -0.078993
# 2          -0.742186 -1.122669 -1.491343 -0.293288  0.753988    -0.273826
# 3          -1.733304 -2.312994 -1.491343 -2.039252  0.753988    -0.457309
# 4           0.295030 -0.788711 -0.929541 -0.282750  0.753988    -0.303145
# ...              ...       ...       ...       ...       ...          ...
# 113995     -2.274962 -1.615656 -0.086838 -1.617326  0.753988    -0.401507
# 113996     -2.263437 -2.084789 -1.491343 -2.000082 -1.326281    -0.421369
# 113997      0.358416 -1.241940 -1.491343 -0.524135 -1.326281    -0.403399
# 113998      0.116398 -0.538241  0.474964 -0.522942  0.753988    -0.519731
# 113999     -0.235103 -0.613780 -1.210442 -0.386740 -1.326281    -0.114933
#
#         acousticness  instrumentalness  liveness   valence     tempo  cluster
# ...

# %%
# Evaluation Matrix
K = range(2, 20)
inertia = []
for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=0)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
kmeans = KMeans(n_clusters = 14, random_state = 0)
kmeans.fit(X_prep)

kmeans.inertia_
# Out:
# 553021.3881299079

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []
for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=0)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))
plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16364/1847537623.py in <module>
#       6                     random_state=0)
#       7     kmeans.fit(X_prep)
# ----> 8     silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))
#       9 plt.figure(figsize=(16,8))
#      10 plt.plot(K, silhouette, 'bx-')
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     212                     )
#     213                 ):
# --> 214                     return func(*args, **kwargs)
#     215             except InvalidParameterError as e:
#     216                 # When the function is just a wrapper around an estimator, we allow
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
# ...

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 14, random_state = 0)
kmeans.fit(X_prep)
kmeans.inertia_
# Out:
# 553021.3881299079

# %%
labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Plotting
plt.figure(figsize=(20, 10))
colors = plt.cm.rainbow(np.linspace(0, 1, len(set(labels))))

for i, color in zip(range(len(cluster_centers)), colors):
    # Plot data points belonging to the current cluster
    plt.scatter(X_prep[labels == i, 0], X_prep[labels == i, 1], color=color, label=f'Cluster {i}')
    # Plot the cluster center
    plt.scatter(cluster_centers[i][0], cluster_centers[i][1], color='black', marker='x', s=100)

plt.title('Clusters formed by KMeans')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
